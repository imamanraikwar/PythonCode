# %%
def breakNumber(n):
    arr = []
    for i in range(n):
        arr.append(1)

# %%
from os import *
from sys import *
from collections import *
from math import *

from os import *
from sys import *
from collections import *
from math import *

from os import *
from sys import *
from collections import *
from math import *

from os import *
from sys import *
from collections import *
from math import *

from os import *
from sys import *
from collections import *
from math import *

## Read input as specified in the question.
## Print output as specified in the question.


def breakNumberHelper(n, rem, arr, ans, st):
    if rem < 0:
        return
    if rem == 0:
        temp = []
        for num in arr:
            temp.append(num)
        temp.sort()
        if temp not in st:
            st.append(temp)
        return
    for i in range(1, n + 1):
        arr.append(i)
        breakNumberHelper(n, rem - i, arr, ans, st)
        arr.pop()

def breakNumber(n):
    ans = []
    arr = []
    st = []
    breakNumberHelper(n, n, arr, ans, st)
    for v in st:
        ans.append(v)
    return ans


n = int(input())
ans = breakNumber(n)
for i in ans :
    print(*i)
    #print()
