# %%
def tringle(n,space):
    for i in range(n):
        for space1 in range(space-i):
            print(' ',end=' ')
        
        if i==(n-1):
            for star in range(2*n-1):
                print('*',end=' ')
        else :
            print('*',end='')
            for space2 in range(i+i):
                print(' ',end=' ')
            if i>0:
                print('*',end=' ')
            print()
    print()
def line(n,space):
    t=(n//2)
    for i in range(n*2):
        for space1 in range(space+t):
            if space1==space-t or space1==space+t-1:
                            print('*',end=' ')
            print(' ',end=' ')
        print()

def circle_print(n,space):
    #temp=2
    t=(n//2)
    for i in range(n):
        for j in range(space+(2*n)):
            #print('1',end=' ')
            if i==0 or i==n-1 :
                if j==(space-n) or j==(space+n) or (i==0 and j==space-t or i==0 and j==space+t) :
                    print('*',end=' ')
                else:
                    print(' ',end=' ')
            elif i<=(n//2) : 
                if  j==(space-n-i) or j==(space-n+i) or j==(space+n-i) or j==(space+n+i) or j==space-t or j==space+t:
                    print('*',end=' ')
                else:
                    print(' ',end=' ')
                    temp = i-1
            elif i>(n//2):
                #print(temp)
                #print(space-n-temp+i,end=' ')
                #temp = i-1
                flag = 3*temp
                if j==(space-n-flag+i) or j==(space-n+flag-i) or j==(space+n-flag+i)  or j==(space+n+flag-i)   :
                    print('*', end=' ')
                    
                else :
                    print(' ', end=' ')                
                            
        print()
   
    
    
space=15
n=7
tringle(n,space) 
line(n,space)
circle_print(n,space)
# Out:
#                               *
#                             *    *
#                           *        *
#                         *            *
#                       *                *
#                     *                    *
#                   * * * * * * * * * * * * *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                         *           *
#                 *       *           *       *
#               *   *     *           *     *   *
#             *       *   *           *   *       *
# ...
